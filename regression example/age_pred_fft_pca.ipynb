# %%
import os
import numpy as np
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.decomposition import PCA

# %%
path = "C:/Users/ychaf/Desktop/age_images"

# %%
img_size = (100, 100)

# %%
features = []
labels = []
for age in os.listdir(path):
    for i, file in enumerate(os.listdir(os.path.join(path, age))):
        if i == 40:
            break
        if file.endswith(".jpg"):
            img = Image.open(os.path.join(path, age, file))
            img = img.resize(img_size)
            img = np.array(img)[...,0].astype(np.uint8) / 255
            res_fft = np.fft.fft2(img)
            res_fft_shift = np.fft.fftshift(res_fft)
            res_fft_log = np.log(abs(res_fft_shift))
            fft_pca = PCA(n_components=1)
            res_fft_pca = fft_pca.fit_transform(res_fft_log)
            res_fft_pca = res_fft_pca.reshape(-1)
            features.append(res_fft_pca)
            labels.append(int(age))

# %%
features = np.array(features)
labels = np.array(labels)

# %%
features.shape, labels.shape
# Out:
# ((480, 100), (480,))

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %% [markdown]
# SVM with FFT and PCA

# %%
svm = SVR()
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 24.211567064336634

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 874.2764474554591

# %%
r2_score(y_test, y_pred)
# Out:
# -0.017219777684012172

# %% [markdown]
# Linear Regression with FFT and PCA

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 27.139685736762157

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1153.4993668562836

# %%
r2_score(y_test, y_pred)
# Out:
# -0.3420953668913467

# %% [markdown]
# XGBoost with FFT and PCA

# %%
xgb = XGBRegressor()
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 23.750576307376225

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 839.1485030568191

# %%
r2_score(y_test, y_pred)
# Out:
# 0.023651550710661717
